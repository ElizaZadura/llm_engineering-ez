# %% [markdown]
# # Code Generator
#
# The requirement: use a Frontier model to generate high performance C++ code from Python code

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder: OPTIONAL to execute C++ code or Rust code</h2>
#             <span style="color:#f71;">As an alternative, you can run it on the website given yesterday</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h1 style="color:#900;">Important Note</h1>
#             <span style="color:#900;">
#             In this lab, I use high end models GPT 5, Claude 4.5 Sonnet, Gemini 2.5 Pro, Grok 4, which are the slightly higher priced models. The costs are still low, but if you'd prefer to keep costs ultra low, please pick lower cost models like gpt-5-nano.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import io
import sys
from dotenv import load_dotenv
from openai import OpenAI
import gradio as gr
import subprocess
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv("OPENAI_API_KEY")
anthropic_api_key = os.getenv("ANTHROPIC_API_KEY")
google_api_key = os.getenv("GOOGLE_API_KEY")
grok_api_key = os.getenv("GROK_API_KEY")
groq_api_key = os.getenv("GROQ_API_KEY")
openrouter_api_key = os.getenv("OPENROUTER_API_KEY")

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")

if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:6]}")
else:
    print("OpenRouter API Key not set (and this is optional)")

# %%
# Connect to client libraries

openai = OpenAI()

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
grok_url = "https://api.x.ai/v1"
groq_url = "https://api.groq.com/openai/v1"
ollama_url = "http://localhost:11434/v1"
openrouter_url = "https://openrouter.ai/api/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)
openrouter = OpenAI(api_key=openrouter_api_key, base_url=openrouter_url)

# %%
models = [
    "gpt-5",
    "claude-sonnet-4-5-20250929",
    "grok-4",
    "gemini-2.5-pro",
    "qwen2.5-coder",
    "deepseek-coder-v2",
    "gpt-oss:20b",
    "qwen/qwen3-coder-30b-a3b-instruct",
    "openai/gpt-oss-120b",
]



clients = {
    "gpt-5": openai,
    "claude-sonnet-4-5-20250929": anthropic,
    "grok-4": grok,
    "gemini-2.5-pro": gemini,
    "openai/gpt-oss-120b": groq,
    "qwen2.5-coder": ollama,
    "deepseek-coder-v2": ollama,
    "gpt-oss:20b": ollama,
    "qwen/qwen3-coder-30b-a3b-instruct": openrouter,
}



# Want to keep costs ultra-low? Replace this with models of your choice, using the examples from yesterday

# %%
from system_info import retrieve_system_info, rust_toolchain_info

system_info = retrieve_system_info()
rust_info = rust_toolchain_info()
rust_info

# %%
message = f"""
Here is a report of the system information for my computer.
I want to run a Rust compiler to compile a single rust file called main.rs and then execute it in the simplest way possible.
Please reply with whether I need to install a Rust toolchain to do this. If so, please provide the simplest step by step instructions to do so.

If I'm already set up to compile Rust code, then I'd like to run something like this in Python to compile and execute the code:
```python
compile_command = # something here - to achieve the fastest possible runtime performance
compile_result = subprocess.run(compile_command, check=True, text=True, capture_output=True)
run_command = # something here
run_result = subprocess.run(run_command, check=True, text=True, capture_output=True)
return run_result.stdout
```
Please tell me exactly what I should use for the compile_command and run_command.
Have the maximum possible runtime performance in mind; compile time can be slow. Fastest possible runtime performance for this platform is key.
Reply with the commands in markdown.

System information:
{system_info}

Rust toolchain information:
{rust_info}
"""

response = openai.chat.completions.create(
    model=models[0], messages=[{"role": "user", "content": message}]
)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# For fastest runtime performance on your machine, compile with high optimization, fat LTO, a single codegen unit, and CPU tuning for your host. In Python, use:
#
# import subprocess
#
# compile_command = [
#     r"C:\Users\eliza\.cargo\bin\rustc.EXE",
#     "-O",
#     "-C", "lto=fat",
#     "-C", "codegen-units=1",
#     "-C", "target-cpu=native",
#     "main.rs",
#     "-o", "main.exe",
# ]
#
# compile_result = subprocess.run(compile_command, check=True, text=True, capture_output=True)
#
# run_command = [r".\main.exe"]
#
# run_result = subprocess.run(run_command, check=True, text=True, capture_output=True)
# print(run_result.stdout)
# Notes:
#
# These flags prioritize runtime speed over compile time.
# target-cpu=native tailors the binary to your i5-12400F; the resulting exe may not run on older CPUs.

# %% [markdown]
# ## For C++, overwrite this with the commands from yesterday, or for Rust, use the new commands
#
# Or just use the website like yesterday:
#
#  https://www.programiz.com/cpp-programming/online-compiler/

# %%
compile_command = [
    r"C:\Users\eliza\.cargo\bin\rustc.EXE",
    "-O",
    "-C",
    "lto=fat",
    "-C",
    "codegen-units=1",
    "-C",
    "target-cpu=native",
    "main.rs",
    "-o",
    "main.exe",
]



run_command = [r".\main.exe"]

# %% [markdown]
# ## And now, on with the main task

# %%
language = "Rust"  # or "C++"
extension = "rs" if language == "Rust" else "cpp"

system_prompt = f"""
Your task is to convert Python code into high performance {language} code.
Respond only with {language} code. Do not provide any explanation other than occasional comments.
The {language} response needs to produce an identical output in the fastest possible time.
"""


def user_prompt_for(python):
    return f"""
Port this Python code to {language} with the fastest possible implementation that produces identical output in the least time.
The system information is:
{system_info}
Your response will be written to a file called main.{language} and then compiled and executed; the compilation command is:
{compile_command}
Respond only with {language} code.
Python code to port:

```python
{python}
```
"""

# %%
def messages_for(python):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(python)},
    ]

# %%
def write_output(code):
    with open(f"main.{extension}", "w") as f:
        f.write(code)

# %%
def port(model, python):
    client = clients[model]
    reasoning_effort = "high" if "gpt" in model else None
    response = client.chat.completions.create(
        model=model, messages=messages_for(python), reasoning_effort=reasoning_effort
    )
    reply = response.choices[0].message.content
    reply = reply.replace("```cpp", "").replace("```rust", "").replace("```", "")
    return reply

# %%
def run_python(code):
    globals_dict = {"__builtins__": __builtins__}

    buffer = io.StringIO()
    old_stdout = sys.stdout
    sys.stdout = buffer

    try:
        exec(code, globals_dict)
        output = buffer.getvalue()
    except Exception as e:
        output = f"Error: {e}"
    finally:
        sys.stdout = old_stdout

    return output

# %%
# Use the commands from GPT 5


def compile_and_run(code):
    write_output(code)
    try:
        subprocess.run(compile_command, check=True, text=True, capture_output=True)
        run_result = subprocess.run(
            run_command, check=True, text=True, capture_output=True
        )
        return run_result.stdout
    except subprocess.CalledProcessError as e:
        return f"An error occurred:\n{e.stderr}"

# %%
python_hard = """# Be careful to support large numbers

def lcg(seed, a=1664525, c=1013904223, m=2**32):
    value = seed
    while True:
        value = (a * value + c) % m
        yield value
        
def max_subarray_sum(n, seed, min_val, max_val):
    lcg_gen = lcg(seed)
    random_numbers = [next(lcg_gen) % (max_val - min_val + 1) + min_val for _ in range(n)]
    max_sum = float('-inf')
    for i in range(n):
        current_sum = 0
        for j in range(i, n):
            current_sum += random_numbers[j]
            if current_sum > max_sum:
                max_sum = current_sum
    return max_sum

def total_max_subarray_sum(n, initial_seed, min_val, max_val):
    total_sum = 0
    lcg_gen = lcg(initial_seed)
    for _ in range(20):
        seed = next(lcg_gen)
        total_sum += max_subarray_sum(n, seed, min_val, max_val)
    return total_sum

# Parameters
n = 10000         # Number of random numbers
initial_seed = 42 # Initial seed for the LCG
min_val = -10     # Minimum value of random numbers
max_val = 10      # Maximum value of random numbers

# Timing the function
import time
start_time = time.time()
result = total_max_subarray_sum(n, initial_seed, min_val, max_val)
end_time = time.time()

print("Total Maximum Subarray Sum (20 runs):", result)
print("Execution Time: {:.6f} seconds".format(end_time - start_time))
"""

# %%
from styles import CSS

with gr.Blocks(
    css=CSS, theme=gr.themes.Monochrome(), title=f"Port from Python to {language}"
) as ui:
    with gr.Row(equal_height=True):
        with gr.Column(scale=6):
            python = gr.Code(
                label="Python (original)",
                value=python_hard,
                language="python",
                lines=26,
            )
        with gr.Column(scale=6):
            cpp = gr.Code(
                label=f"{language} (generated)", value="", language="cpp", lines=26
            )

    with gr.Row(elem_classes=["controls"]):
        python_run = gr.Button("Run Python", elem_classes=["run-btn", "py"])
        model = gr.Dropdown(models, value=models[0], show_label=False)
        convert = gr.Button(f"Port to {language}", elem_classes=["convert-btn"])
        cpp_run = gr.Button(f"Run {language}", elem_classes=["run-btn", "cpp"])

    with gr.Row(equal_height=True):
        with gr.Column(scale=6):
            python_out = gr.TextArea(
                label="Python result", lines=8, elem_classes=["py-out"]
            )
        with gr.Column(scale=6):
            cpp_out = gr.TextArea(
                label=f"{language} result", lines=8, elem_classes=["cpp-out"]
            )

    convert.click(fn=port, inputs=[model, python], outputs=[cpp])
    python_run.click(fn=run_python, inputs=[python], outputs=[python_out])
    cpp_run.click(fn=compile_and_run, inputs=[cpp], outputs=[cpp_out])

ui.launch(inbrowser=True)

# %% [markdown]
# ## RESULTS!
#
# Python code: 37.967828 seconds
#
# ---
#
# Qwen 2.5 Coder: FAIL
#
# GPT-oss-120B: FAIL (no output?)
#
# **GPT-oss-20B: 0.000268 seconds**
#
# Qwen3 Coder 30B: FAIL
#
# Gemini 2.5 Pro: FAIL
#
# DeepSeek Coder v2: FAIL
#
# Claude Sonnet 4.5: 0.279476 seconds
#
# GPT-5: FAIL
#
# Grok 4: FAIL

# %%
print(
    f"In Ed's experimenet, the GPT-OSS 120B model outcome is {33.755209/0.000304:,.0f} times faster than the Python code."
)

# %%
# !ollama pull deepseek-coder-v2
# Out:
# ^C
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏ 1.4 KB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏ 549 KB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏ 1.3 MB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏ 2.3 MB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏ 3.9 MB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏ 4.8 MB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏ 6.1 MB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏ 7.6 MB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏ 8.4 MB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏ 9.8 MB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  11 MB/8.9 GB   11 MB/s  12m57spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  12 MB/8.9 GB   11 MB/s  12m57spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  13 MB/8.9 GB   11 MB/s  12m56spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  14 MB/8.9 GB   11 MB/s  12m56spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  15 MB/8.9 GB   11 MB/s  12m56spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  17 MB/8.9 GB   11 MB/s  12m56spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  18 MB/8.9 GB   11 MB/s  12m56spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  19 MB/8.9 GB   11 MB/s  12m56spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  20 MB/8.9 GB   11 MB/s  12m56spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  22 MB/8.9 GB   11 MB/s  12m56spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  22 MB/8.9 GB   11 MB/s  12m56spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  24 MB/8.9 GB   11 MB/s  12m41spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  25 MB/8.9 GB   11 MB/s  12m40spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  26 MB/8.9 GB   11 MB/s  12m40spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  27 MB/8.9 GB   11 MB/s  12m40spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  29 MB/8.9 GB   11 MB/s  12m40spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  29 MB/8.9 GB   11 MB/s  12m40spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  31 MB/8.9 GB   11 MB/s  12m40spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  32 MB/8.9 GB   11 MB/s  12m40spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  33 MB/8.9 GB   11 MB/s  12m40spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  34 MB/8.9 GB   11 MB/s  12m40spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  36 MB/8.9 GB   11 MB/s  12m28spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  36 MB/8.9 GB   11 MB/s  12m27spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  38 MB/8.9 GB   11 MB/s  12m27spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  39 MB/8.9 GB   11 MB/s  12m27spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  40 MB/8.9 GB   11 MB/s  12m27spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  41 MB/8.9 GB   11 MB/s  12m27spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  43 MB/8.9 GB   11 MB/s  12m27spulling manifest
# pulling 5ff0abeeac1d:   0% ▕                  ▏  43 MB/8.9 GB   11 MB/s  12m27spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  45 MB/8.9 GB   11 MB/s  12m27spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  46 MB/8.9 GB   11 MB/s  12m27spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  47 MB/8.9 GB   11 MB/s  12m23spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  48 MB/8.9 GB   11 MB/s  12m23spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  50 MB/8.9 GB   11 MB/s  12m23spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  51 MB/8.9 GB   11 MB/s  12m23spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  52 MB/8.9 GB   11 MB/s  12m23spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  54 MB/8.9 GB   11 MB/s  12m22spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  54 MB/8.9 GB   11 MB/s  12m22spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  56 MB/8.9 GB   11 MB/s  12m22spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  57 MB/8.9 GB   11 MB/s  12m22spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  58 MB/8.9 GB   11 MB/s  12m22spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  59 MB/8.9 GB   11 MB/s  12m22spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  61 MB/8.9 GB   11 MB/s  12m22spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  61 MB/8.9 GB   11 MB/s  12m22spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  63 MB/8.9 GB   11 MB/s  12m22spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  64 MB/8.9 GB   11 MB/s  12m22spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  65 MB/8.9 GB   11 MB/s  12m21spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  66 MB/8.9 GB   11 MB/s  12m21spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  68 MB/8.9 GB   11 MB/s  12m21spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  68 MB/8.9 GB   11 MB/s  12m21spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  70 MB/8.9 GB   11 MB/s  12m21spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  71 MB/8.9 GB   11 MB/s  12m19spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  72 MB/8.9 GB   11 MB/s  12m19spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  73 MB/8.9 GB   11 MB/s  12m19spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  75 MB/8.9 GB   11 MB/s  12m18spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  75 MB/8.9 GB   11 MB/s  12m18spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  77 MB/8.9 GB   11 MB/s  12m18spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  78 MB/8.9 GB   11 MB/s  12m18spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  79 MB/8.9 GB   11 MB/s  12m18spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  80 MB/8.9 GB   11 MB/s  12m18spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  82 MB/8.9 GB   11 MB/s  12m18spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  83 MB/8.9 GB   11 MB/s  12m18spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  84 MB/8.9 GB   11 MB/s  12m16spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  85 MB/8.9 GB   11 MB/s  12m16spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  86 MB/8.9 GB   11 MB/s  12m16spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  88 MB/8.9 GB   11 MB/s  12m16spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  89 MB/8.9 GB   11 MB/s  12m16spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  90 MB/8.9 GB   11 MB/s  12m16spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  91 MB/8.9 GB   11 MB/s  12m16spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  93 MB/8.9 GB   11 MB/s  12m16spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  93 MB/8.9 GB   11 MB/s  12m16spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  95 MB/8.9 GB   11 MB/s  12m16spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  96 MB/8.9 GB   11 MB/s  12m15spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  97 MB/8.9 GB   11 MB/s  12m14spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏  98 MB/8.9 GB   11 MB/s  12m14spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 100 MB/8.9 GB   11 MB/s  12m14spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 100 MB/8.9 GB   11 MB/s  12m14spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 102 MB/8.9 GB   11 MB/s  12m14spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 103 MB/8.9 GB   11 MB/s  12m14spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 104 MB/8.9 GB   11 MB/s  12m14spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 105 MB/8.9 GB   11 MB/s  12m14spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 107 MB/8.9 GB   11 MB/s  12m14spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 107 MB/8.9 GB   11 MB/s  12m13spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 109 MB/8.9 GB   11 MB/s  12m13spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 110 MB/8.9 GB   11 MB/s  12m13spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 111 MB/8.9 GB   11 MB/s  12m13spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 112 MB/8.9 GB   11 MB/s  12m13spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 114 MB/8.9 GB   11 MB/s  12m13spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 115 MB/8.9 GB   11 MB/s  12m12spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 116 MB/8.9 GB   11 MB/s  12m12spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 117 MB/8.9 GB   11 MB/s  12m12spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 118 MB/8.9 GB   11 MB/s  12m12spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 120 MB/8.9 GB   12 MB/s   12m8spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 121 MB/8.9 GB   12 MB/s   12m8spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 122 MB/8.9 GB   12 MB/s   12m7spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 123 MB/8.9 GB   12 MB/s   12m7spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 125 MB/8.9 GB   12 MB/s   12m7spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 125 MB/8.9 GB   12 MB/s   12m7spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 127 MB/8.9 GB   12 MB/s   12m7spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 128 MB/8.9 GB   12 MB/s   12m7spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 129 MB/8.9 GB   12 MB/s   12m7spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 130 MB/8.9 GB   12 MB/s   12m7spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 132 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   1% ▕                  ▏ 132 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 134 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 135 MB/8.9 GB   12 MB/s   12m5spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 136 MB/8.9 GB   12 MB/s   12m5spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 137 MB/8.9 GB   12 MB/s   12m5spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 139 MB/8.9 GB   12 MB/s   12m5spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 139 MB/8.9 GB   12 MB/s   12m5spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 141 MB/8.9 GB   12 MB/s   12m5spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 142 MB/8.9 GB   12 MB/s   12m5spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 143 MB/8.9 GB   12 MB/s   12m5spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 144 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 146 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 146 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 148 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 149 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 150 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 151 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 153 MB/8.9 GB   12 MB/s   12m5spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 153 MB/8.9 GB   12 MB/s   12m5spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 155 MB/8.9 GB   12 MB/s   12m5spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 156 MB/8.9 GB   12 MB/s   12m7spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 157 MB/8.9 GB   12 MB/s   12m7spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 158 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 160 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 160 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 162 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 163 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 164 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 165 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 167 MB/8.9 GB   12 MB/s   12m6spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 167 MB/8.9 GB   12 MB/s   12m5spulling manifest
# pulling 5ff0abeeac1d:   2% ▕                  ▏ 169 MB/8.9 GB   12 MB/s   12m5spulling manifest pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB                  pulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m53spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m53spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m53spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m53spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m53spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m53spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m53spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m53spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m52spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m52spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   10m9spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   10m9spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   10m9spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   10m9spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   10m9spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   10m9spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   10m9spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   10m8spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   10m8spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   10m8spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   10m8spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   10m0spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   10m0spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   10m0spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   10m0spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m59spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m59spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m59spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m59spulling manifest
# pulling 5ff0abeeac1d:  20% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m59spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m59spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m56spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m56spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m55spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m55spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m55spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m55spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m55spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m55spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m55spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m55spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m52spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m52spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m52spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m52spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m52spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m52spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m51spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m51spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.8 GB/8.9 GB   11 MB/s   9m51spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m51spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m50spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m50spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m50spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m50spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m50spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m50spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m50spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m50spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m50spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m49spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m48spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m48spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m48spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m48spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m48spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m48spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m48spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m47spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m47spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m47spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m47spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m47spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m47spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m46spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m46spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m46spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m46spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m46spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m46spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m46spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m46spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m44spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m44spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m44spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m44spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m44spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m44spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m44spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m44spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m44spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   11 MB/s   9m43spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m43spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m43spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m43spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m43spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m43spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m43spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m43spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m42spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m42spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m42spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m39spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m39spulling manifest
# pulling 5ff0abeeac1d:  21% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m39spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m39spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m39spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m39spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m39spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m39spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m38spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m38spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m38spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m38spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m38spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m38spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m38spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m38spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m38spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m38spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m38spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m38spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m38spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m38spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 1.9 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m37spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m35spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m35spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m35spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m35spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m35spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m34spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m34spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m34spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m34spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m34spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m35spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m35spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m35spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m35spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m35spulling manifest
# pulling 5ff0abeeac1d:  22% ▕███               ▏ 2.0 GB/8.9 GB   12 MB/s   9m35spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m35spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m35spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m35spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m34spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m34spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m34spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m33spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m33spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m33spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m33spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m33spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m33spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m33spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m33spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m33spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m32spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m32spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m32spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m32spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m32spulling manifest
# pulling 5ff0abeeac1d:  22% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m32spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m32spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m32spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m32spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m32spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m29spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m29spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m29spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m29spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m29spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   11 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   11 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   11 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   11 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   11 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.0 GB/8.9 GB   11 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m31spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m30spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m29spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m29spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m29spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m28spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  23% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m26spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m26spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m26spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m27spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m25spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m25spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m25spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m25spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m25spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m25spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m25spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m25spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m25spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m25spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m24spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m24spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m23spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m23spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m23spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m23spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m23spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m23spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m23spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   12 MB/s   9m23spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m24spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m24spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m24spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m24spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m24spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m24spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m24spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.1 GB/8.9 GB   11 MB/s   9m24spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m24spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m24spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   12 MB/s   9m19spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   12 MB/s   9m19spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   12 MB/s   9m19spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   12 MB/s   9m19spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   12 MB/s   9m19spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   12 MB/s   9m18spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   12 MB/s   9m18spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   12 MB/s   9m18spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   12 MB/s   9m18spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   12 MB/s   9m18spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m21spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m21spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m21spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m21spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m21spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m21spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m21spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m21spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m21spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m20spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m20spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m20spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m20spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m20spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m20spulling manifest
# pulling 5ff0abeeac1d:  24% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m20spulling manifest
# pulling 5ff0abeeac1d:  25% ▕████              ▏ 2.2 GB/8.9 GB   11 MB/s   9m20spulling manifest
# ...
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 5ff0abeeac1d: 100% ▕██████████████████▏ 8.9 GB
# pulling 22091531faf0: 100% ▕██████████████████▏  705 B
# pulling 4bb71764481f: 100% ▕██████████████████▏  13 KB
# pulling 1c8f573e830c: 100% ▕██████████████████▏ 1.1 KB
# pulling 19f2fb9e8bc6: 100% ▕██████████████████▏   32 B
# pulling 34488e453cfe: 100% ▕██████████████████▏  568 B
# verifying sha256 digest
# writing manifest
# success
# Traceback (most recent call last):
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpx\_transports\default.py", line 101, in map_httpcore_exceptions
#     yield
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpx\_transports\default.py", line 250, in handle_request
#     resp = self._pool.handle_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py", line 256, in handle_request
#     raise exc from None
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py", line 236, in handle_request
#     response = connection.handle_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpcore\_sync\connection.py", line 103, in handle_request
#     return self._connection.handle_request(request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpcore\_sync\http11.py", line 136, in handle_request
#     raise exc
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpcore\_sync\http11.py", line 106, in handle_request
#     ) = self._receive_response_headers(**kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpcore\_sync\http11.py", line 177, in _receive_response_headers
#     event = self._receive_event(timeout=timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpcore\_sync\http11.py", line 217, in _receive_event
#     data = self._network_stream.read(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpcore\_backends\sync.py", line 126, in read
#     with map_exceptions(exc_map):
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\eliza\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\contextlib.py", line 158, in __exit__
#     self.gen.throw(value)
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpcore\_exceptions.py", line 14, in map_exceptions
#     raise to_exc(exc) from exc
# httpcore.ReadTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\openai\_base_client.py", line 982, in request
#     response = self._client.send(
#                ^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpx\_client.py", line 914, in send
#     response = self._send_handling_auth(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpx\_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpx\_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpx\_client.py", line 1014, in _send_single_request
#     response = transport.handle_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpx\_transports\default.py", line 249, in handle_request
#     with map_httpcore_exceptions():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\eliza\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\contextlib.py", line 158, in __exit__
#     self.gen.throw(value)
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\httpx\_transports\default.py", line 118, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.ReadTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\gradio\queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\gradio\route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\gradio\blocks.py", line 2116, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\gradio\blocks.py", line 1623, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 2485, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 976, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\gradio\utils.py", line 915, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\eliza\AppData\Local\Temp\ipykernel_11292\53002502.py", line 4, in port
#     response = client.chat.completions.create(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\openai\_utils\_utils.py", line 286, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py", line 1156, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\openai\_base_client.py", line 1259, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Dev\Learning\llm_engineering\llm_engineering-ez\.venv\Lib\site-packages\openai\_base_client.py", line 1000, in request
#     raise APITimeoutError(request=request) from err
# openai.APITimeoutError: Request timed out.
